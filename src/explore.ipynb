# %% [markdown]
# # Explore here

# %%
import pandas as pd


df= pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/data-preprocessing-project-tutorial/main/AB_NYC_2019.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.to_csv('../data/raw/raw_data.scv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.drop("id", axis = 1).duplicated().sum()
# Out:
# 0

# %%
#eliminar informacion irrelevante
irrelevant_columns=['name','id','host_id','host_name','reviews_per_month','last_review']
df.drop(irrelevant_columns, axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  object
#  1   neighbourhood                   48895 non-null  object
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  object
#  5   price                           48895 non-null  int64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   calculated_host_listings_count  48895 non-null  int64
#  9   availability_365                48895 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 3.7+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, axis = plt.subplots(2, 3, figsize = (10, 7))

sns.histplot(ax = axis[0, 0], data = df, x = "neighbourhood_group").set(ylabel=None, xticks=[])
sns.histplot(ax=axis[0,1],data= df, x = "neighbourhood" ).set(ylabel = None, xticks=[])
sns.histplot(ax=axis[0,2],data= df, x = "room_type" ).set_xticklabels(axis[0,2].get_xticklabels(),rotation=30, ha="right")
sns.histplot(ax=axis[1,0],data=df,x="availability_365").set(ylabel=None,xticks=[])

plt.tight_layout()

plt.show()

#las variables categoricas son las que dicen object
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_12256\1488476905.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.histplot(ax=axis[0,2],data= df, x = "room_type" ).set_xticklabels(axis[0,2].get_xticklabels(),rotation=30, ha="right")

# %%
#variables numericas


fig, axis= plt.subplots(4,2, figsize= (10,7), gridspec_kw= {'height_ratios': [6, 6, 1, 1]}) # Ajusta height_ratios
sns.histplot(ax = axis[0, 0], data = df, x = "price").set_xlim(0,80)
sns.boxplot(ax = axis[1, 0], data = df, x = "price")

sns.histplot(ax = axis[0, 1], data = df, x = "minimum_nights").set_xlim(0,80)
sns.boxplot(ax = axis[1, 1], data = df, x = "minimum_nights")


sns.histplot(ax = axis[2,0], data = df, x = "calculated_host_listings_count").set_xlim(0,80)
sns.boxplot(ax = axis[3,0], data = df, x = "calculated_host_listings_count")

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
#analisis multivariante
